# %%
pip install arch
# Out:
# Requirement already satisfied: arch in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (6.2.0)
# Requirement already satisfied: numpy>=1.19 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from arch) (1.26.2)
# Requirement already satisfied: scipy>=1.5 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from arch) (1.11.3)
# Requirement already satisfied: pandas>=1.1 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from arch) (2.1.3)
# Requirement already satisfied: statsmodels>=0.12 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from arch) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ivan\appdata\roaming\python\python312\site-packages (from pandas>=1.1->arch) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.1->arch) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.1->arch) (2023.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from statsmodels>=0.12->arch) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\ivan\appdata\roaming\python\python312\site-packages (from statsmodels>=0.12->arch) (23.2)
# Requirement already satisfied: six in c:\users\ivan\appdata\roaming\python\python312\site-packages (from patsy>=0.5.2->statsmodels>=0.12->arch) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (1.26.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ivan\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ivan\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ivan\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ivan\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.6 kB 640.0 kB/s eta 0:00:01
#    ---- ---------------------------------- 30.7/294.6 kB 640.0 kB/s eta 0:00:01
#    -------------- ----------------------- 112.6/294.6 kB 930.9 kB/s eta 0:00:01
#    -------------- ----------------------- 112.6/294.6 kB 930.9 kB/s eta 0:00:01
#    -------------- ----------------------- 112.6/294.6 kB 930.9 kB/s eta 0:00:01
#    -------------- ----------------------- 112.6/294.6 kB 930.9 kB/s eta 0:00:01
#    ------------------------------ ------- 235.5/294.6 kB 719.7 kB/s eta 0:00:01
#    ------------------------------ ------- 235.5/294.6 kB 719.7 kB/s eta 0:00:01
#    ------------------------------------ - 286.7/294.6 kB 655.2 kB/s eta 0:00:01
#    -------------------------------------- 294.6/294.6 kB 673.8 kB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, acf
from statsmodels.tsa.arima.model import ARIMA
from arch import arch_model

from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.graphics.gofplots import qqplot

import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns

sns.set_style("darkgrid")
plt.rc("figure", figsize=(16, 6))
plt.rc("savefig", dpi=90)
plt.rc("font", family="sans-serif")
plt.rc("font", size=14)

# %% [markdown]
# ### Данные
#
# BP - британский фунт, CD - канадский доллар, DM - немецкая марка, DDM - разность логарифмов DM, DY - , SF - франк

# %%
df = pd.read_csv(r'garch.csv')
df
# Out:
#           BP      CD    DATE  DAY       DDM      DM        DY      SF
# 0     2.2490  0.8547  800102    3       NaN  0.5861  0.004206  0.6365
# 1     2.2365  0.8552  800103    4 -0.004103  0.5837  0.004187  0.6357
# 2     2.2410  0.8566  800104    5  0.000856  0.5842  0.004269  0.6355
# 3     2.2645  0.8538  800107    1  0.001881  0.5853  0.004315  0.6373
# 4     2.2560  0.8553  800108    2 -0.004967  0.5824  0.004257  0.6329
# ...      ...     ...     ...  ...       ...     ...       ...     ...
# 1862  1.6800  0.7457  870515    5  0.002136  0.5625  0.007158  0.6839
# 1863  1.6815  0.7451  870518    1 -0.002492  0.5611  0.007130  0.6832
# 1864  1.6865  0.7442  870519    2  0.006218  0.5646  0.007165  0.6882
# 1865  1.6805  0.7414  870520    3 -0.002483  0.5632  0.007147  0.6865
# 1866  1.6795  0.7421  870521    4 -0.000888  0.5627  0.007107  0.6861
#
# [1867 rows x 8 columns]

# %%
def corr_plot(df, zero=True):
    fig = plt.figure(figsize=(15, 8))
    gs = gridspec.GridSpec(2, 4)
    gs.update(wspace=0.5)
    ax1 = fig.add_subplot(gs[0, :])
    ax2 = fig.add_subplot(gs[1, :2])
    ax3 = fig.add_subplot(gs[1, 2:])
    df.plot(ax=ax1)
    plot_acf(df, zero=zero, ax=ax2)
    plot_pacf(df, zero=zero, ax=ax3)
    plt.show();

# %%
corr_plot(df.DM)

# %%
corr_plot(df.DDM[1:], zero=False)

# %% [markdown]
# ### Как определить волатильность: остатки модели

# %%
m = ARIMA(df.DDM, order=(0, 0, 0)).fit()
print(m.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    DDM   No. Observations:                 1867
# Model:                          ARIMA   Log Likelihood                6417.141
# Date:                Sat, 23 Dec 2023   AIC                         -12830.283
# Time:                        14:10:10   BIC                         -12819.219
# Sample:                             0   HQIC                        -12826.206
#                                - 1867
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.676e-05      0.000     -0.145      0.885      -0.000       0.000
# sigma2      6.032e-05   1.39e-06     43.361      0.000    5.76e-05     6.3e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   6.73   Jarque-Bera (JB):               450.84
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.44   Skew:                             0.45
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.23
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
(m.resid**2).plot();

# %% [markdown]
# ### ARCH(1)
#
# $ y_t = \varepsilon_t $
#
# $ \sigma_t = \nu_t \cdot \varepsilon_t $
#
# $ \sigma_t^2 = \omega + \alpha_1 \cdot \varepsilon_{t-1}^2 $

# %%
arch_model(y=df.DDM.dropna()*100, mean='Zero', vol='ARCH', p=1).fit()  #*100
# Out:
# Iteration:      1,   Func. Count:      4,   Neg. LLF: 21653460.916798472
# Iteration:      2,   Func. Count:      9,   Neg. LLF: 2587.371039895222
# Iteration:      3,   Func. Count:     15,   Neg. LLF: 2152.975747621693
# Iteration:      4,   Func. Count:     17,   Neg. LLF: 2152.975747621437
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2152.975747621693
#             Iterations: 4
#             Function evaluations: 17
#             Gradient evaluations: 4
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1890: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if isinstance(table_val[pos], (np.float64, float)):
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1891: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   assert isinstance(table_val[pos], float)
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1892: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   converted = format_float_fixed(table_val[pos], *formats[i])
#                         Zero Mean - ARCH Model Results
# ==============================================================================
# Dep. Variable:                    DDM   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.001
# Vol Model:                       ARCH   Log-Likelihood:               -2152.98
# Distribution:                  Normal   AIC:                           4309.95
# Method:            Maximum Likelihood   BIC:                           4321.01
#                                         No. Observations:                 1866
# Date:                Sat, Dec 23 2023   Df Residuals:                     1866
# Time:                        14:12:03   Df Model:                            0
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.5098  2.783e-02     18.320  5.712e-75   [  0.455,  0.564]
# alpha[1]       0.1576  4.994e-02      3.155  1.603e-03 [5.970e-02,  0.255]
# ==========================================================================
#
# Covariance estimator: robust
# ARCHModelResult, id: 0x1e9da3660f0

# %% [markdown]
# ### ARCH(1) с константой
#
# $ y_t = \mu + \varepsilon_t $
#
# $ \sigma_t = \nu_t \cdot \varepsilon_t $
#
# $ \sigma_t^2 = \omega + \alpha_1 \cdot \varepsilon_{t-1}^2 $

# %%
arch_model(y=df.DDM.dropna()*100, mean='Constant', vol='ARCH', p=1).fit()
# Out:
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 12180.12553673586
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 613771.3140197357
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 2586.656463160447
# Iteration:      4,   Func. Count:     26,   Neg. LLF: 2152.765242353861
# Iteration:      5,   Func. Count:     29,   Neg. LLF: 2152.765242353887
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2152.765242353861
#             Iterations: 5
#             Function evaluations: 29
#             Gradient evaluations: 5
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1890: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if isinstance(table_val[pos], (np.float64, float)):
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1891: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   assert isinstance(table_val[pos], float)
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1892: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   converted = format_float_fixed(table_val[pos], *formats[i])
#                       Constant Mean - ARCH Model Results
# ==============================================================================
# Dep. Variable:                    DDM   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                       ARCH   Log-Likelihood:               -2152.77
# Distribution:                  Normal   AIC:                           4311.53
# Method:            Maximum Likelihood   BIC:                           4328.13
#                                         No. Observations:                 1866
# Date:                Sat, Dec 23 2023   Df Residuals:                     1865
# Time:                        14:13:44   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu            -0.0112  1.735e-02     -0.644      0.519 [-4.519e-02,2.283e-02]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.5091  2.807e-02     18.135  1.682e-73   [  0.454,  0.564]
# alpha[1]       0.1591  5.063e-02      3.141  1.681e-03 [5.982e-02,  0.258]
# ==========================================================================
#
# Covariance estimator: robust
# ARCHModelResult, id: 0x1e9d9d3f980

# %% [markdown]
# ### AR(1)-GARCH(1, 1)
#
# $ y_t = \mu + a \cdot y_{t-1} + \varepsilon_t $
#
# $ \sigma_t = \nu_t \cdot \varepsilon_t $
#
# $ \sigma_t^2 = \omega + \alpha_1 \cdot \varepsilon_{t-1}^2 + \beta_1 \cdot \sigma_{t-1}^2 $

# %%
model_garch = arch_model(y=df.DDM.dropna()*100, mean='ARX', lags=1, vol='GARCH', p=1, q=1).fit(update_freq=0)
print(model_garch.summary())
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2058.239281049041
#             Iterations: 12
#             Function evaluations: 91
#             Gradient evaluations: 12
#                            AR - GARCH Model Results
# ==============================================================================
# Dep. Variable:                    DDM   R-squared:                       0.003
# Mean Model:                        AR   Adj. R-squared:                  0.002
# Vol Model:                      GARCH   Log-Likelihood:               -2058.24
# Distribution:                  Normal   AIC:                           4126.48
# Method:            Maximum Likelihood   BIC:                           4154.13
#                                         No. Observations:                 1865
# Date:                Fri, Dec 22 2023   Df Residuals:                     1863
# Time:                        21:54:58   Df Model:                            2
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# Const         -0.0236  1.639e-02     -1.439      0.150 [-5.572e-02,8.548e-03]
# DDM[1]        -0.0771  2.451e-02     -3.146  1.653e-03   [ -0.125,-2.908e-02]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0133  4.936e-03      2.685  7.260e-03 [3.578e-03,2.293e-02]
# alpha[1]       0.1022  2.099e-02      4.866  1.138e-06   [6.101e-02,  0.143]
# beta[1]        0.8807  2.187e-02     40.263      0.000     [  0.838,  0.924]
# ============================================================================
#
# Covariance estimator: robust
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1890: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if isinstance(table_val[pos], (np.float64, float)):
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1891: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   assert isinstance(table_val[pos], float)
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1892: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   converted = format_float_fixed(table_val[pos], *formats[i])

# %%
model_garch.plot();

# %%
plt.plot(model_garch.conditional_volatility);

# %% [markdown]
# Посмотрим на стандартизированные ошибки $ \nu_t $. В хорошей модели они - белый шум с мат. ожиданием 0 и дисперсией 1

# %%
corr_plot(model_garch.std_resid.dropna(), zero=False) # стандартизированные ошибки \nu_t

# %%
model_garch.std_resid.mean(), model_garch.std_resid.std()
# Out:
# (0.009882658444169815, 0.9994719726843101)

# %%
acorr_ljungbox(model_garch.std_resid[1:], model_df=2)
# Out:
#       lb_stat  lb_pvalue
# 1    3.258278        NaN
# 2    8.978943        NaN
# 3   16.587138   0.000046
# 4   16.789793   0.000226
# 5   24.533167   0.000019
# 6   25.515512   0.000040
# 7   25.861381   0.000095
# 8   26.882542   0.000152
# 9   29.213040   0.000132
# 10  29.619539   0.000247

# %%
qqplot(model_garch.std_resid, line='45');

# %% [markdown]
# ### GJR-GARCH(1, 1)
#
# $ y_t = \mu + \varepsilon_t $
#
# $ \sigma_t = \nu_t \cdot \varepsilon_t $
#
# $ \sigma_t^2 = \omega + \alpha_1 \varepsilon_{t-1}^2 + \gamma_1 \varepsilon_{t-1}^2 I_{[\varepsilon_{t-1}<0]} + \beta_1 \sigma_{t-1} $

# %%
gjr_garch = arch_model(y=df.DDM.dropna()*100, mean='Constant', vol='GARCH', p=1, o=1, q=1).fit(update_freq=0)
print(gjr_garch.summary())
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2061.941036046608
#             Iterations: 13
#             Function evaluations: 95
#             Gradient evaluations: 13
#                    Constant Mean - GJR-GARCH Model Results
# ==============================================================================
# Dep. Variable:                    DDM   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                  GJR-GARCH   Log-Likelihood:               -2061.94
# Distribution:                  Normal   AIC:                           4133.88
# Method:            Maximum Likelihood   BIC:                           4161.54
#                                         No. Observations:                 1866
# Date:                Fri, Dec 22 2023   Df Residuals:                     1865
# Time:                        22:05:52   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu            -0.0293  1.589e-02     -1.846  6.482e-02 [-6.049e-02,1.803e-03]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega          0.0109  4.826e-03      2.259  2.388e-02  [1.443e-03,2.036e-02]
# alpha[1]       0.0788  2.510e-02      3.138  1.698e-03    [2.958e-02,  0.128]
# gamma[1]       0.0352  2.179e-02      1.615      0.106 [-7.514e-03,7.789e-02]
# beta[1]        0.8916  2.349e-02     37.951      0.000      [  0.846,  0.938]
# =============================================================================
#
# Covariance estimator: robust
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1890: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if isinstance(table_val[pos], (np.float64, float)):
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1891: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   assert isinstance(table_val[pos], float)
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1892: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   converted = format_float_fixed(table_val[pos], *formats[i])

# %%
acorr_ljungbox(gjr_garch.std_resid[1:]) # только на первом лаге остатки - белый шум
# Out:
#       lb_stat  lb_pvalue
# 1    2.040118   0.153198
# 2    7.342648   0.025443
# 3   15.347520   0.001543
# 4   16.255944   0.002694
# 5   23.953545   0.000222
# 6   24.533900   0.000416
# 7   24.765821   0.000835
# 8   25.524944   0.001266
# 9   27.443206   0.001181
# 10  27.882749   0.001885

# %% [markdown]
# ### TARCH
#
# $ y_t = \mu + \varepsilon_t $
#
# $ \sigma_t = \nu_t \cdot \varepsilon_t $
#
# $ \sigma_t = \omega + \alpha_1 \cdot |\varepsilon_{t-1}| + \gamma_1 |\varepsilon_{t-1}| I_{[\varepsilon_{t-1}<0]} + \beta_1 \cdot |\sigma_{t-1}| $

# %%
tarch = arch_model(y=df.DDM.dropna()*100, mean='Constant', vol='GARCH', p=1, o=1, q=1, power=1.0).fit(update_freq=0)
print(tarch.summary())
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2061.162525044846
#             Iterations: 15
#             Function evaluations: 110
#             Gradient evaluations: 15
#                   Constant Mean - TARCH/ZARCH Model Results
# ==============================================================================
# Dep. Variable:                    DDM   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                TARCH/ZARCH   Log-Likelihood:               -2061.16
# Distribution:                  Normal   AIC:                           4132.33
# Method:            Maximum Likelihood   BIC:                           4159.98
#                                         No. Observations:                 1866
# Date:                Fri, Dec 22 2023   Df Residuals:                     1865
# Time:                        22:08:49   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu            -0.0298  1.556e-02     -1.914  5.565e-02 [-6.029e-02,7.193e-04]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega          0.0187  6.291e-03      2.972  2.954e-03  [6.370e-03,3.103e-02]
# alpha[1]       0.0910  1.916e-02      4.752  2.016e-06    [5.349e-02,  0.129]
# gamma[1]       0.0200  1.604e-02      1.246      0.213 [-1.145e-02,5.141e-02]
# beta[1]        0.8986  1.754e-02     51.225      0.000      [  0.864,  0.933]
# =============================================================================
#
# Covariance estimator: robust
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1890: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if isinstance(table_val[pos], (np.float64, float)):
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1891: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   assert isinstance(table_val[pos], float)
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1892: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   converted = format_float_fixed(table_val[pos], *formats[i])

# %%
acorr_ljungbox(tarch.std_resid[1:]) # не белый шум
# Out:
#       lb_stat  lb_pvalue
# 1    2.188988   0.139001
# 2    7.255317   0.026578
# 3   15.743717   0.001280
# 4   16.701111   0.002209
# 5   24.664641   0.000162
# 6   25.346068   0.000295
# 7   25.737099   0.000561
# 8   26.398939   0.000897
# 9   28.289746   0.000853
# 10  28.704200   0.001391

# %% [markdown]
# ### GJR-GARCH with Student-T Errors
#
# $ y_t = \mu + \varepsilon_t $
#
# $ \sigma_t = \nu_t \cdot \varepsilon_t, \nu_t \sim StudentT(\nu) $
#
# $ \sigma_t^2 = \omega + \alpha_1 \varepsilon_{t-1}^2 + \gamma_1 \varepsilon_{t-1}^2 I_{[\varepsilon_{t-1}<0]} + \beta_1 \sigma_{t-1} $

# %%
gjr_garch_t = arch_model(y=df.DDM.dropna()*100, mean='Constant', vol='GARCH', p=1, o=1, q=1, dist='StudentsT').fit(update_freq=0)
print(gjr_garch_t.summary())
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2041.8501088321998
#             Iterations: 12
#             Function evaluations: 100
#             Gradient evaluations: 12
#                       Constant Mean - GJR-GARCH Model Results
# ====================================================================================
# Dep. Variable:                          DDM   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                        GJR-GARCH   Log-Likelihood:               -2041.85
# Distribution:      Standardized Student's t   AIC:                           4095.70
# Method:                  Maximum Likelihood   BIC:                           4128.89
#                                               No. Observations:                 1866
# Date:                      Fri, Dec 22 2023   Df Residuals:                     1865
# Time:                              22:10:44   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                  coef    std err          t      P>|t|        95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu            -0.0341  1.530e-02     -2.228  2.589e-02 [-6.409e-02,-4.100e-03]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega          0.0103  4.513e-03      2.286  2.224e-02  [1.473e-03,1.916e-02]
# alpha[1]       0.0750  2.131e-02      3.518  4.341e-04    [3.321e-02,  0.117]
# gamma[1]       0.0314  2.055e-02      1.527      0.127 [-8.907e-03,7.166e-02]
# beta[1]        0.8977  2.073e-02     43.301      0.000      [  0.857,  0.938]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu             9.2200      1.906      4.836  1.324e-06 [  5.483, 12.957]
# ========================================================================
#
# Covariance estimator: robust
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1890: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if isinstance(table_val[pos], (np.float64, float)):
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1891: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   assert isinstance(table_val[pos], float)
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1892: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   converted = format_float_fixed(table_val[pos], *formats[i])

# %%
acorr_ljungbox(gjr_garch_t.std_resid[1:])
# Out:
#       lb_stat  lb_pvalue
# 1    2.142059   0.143309
# 2    7.321251   0.025716
# 3   15.169365   0.001677
# 4   16.131466   0.002848
# 5   23.715258   0.000246
# 6   24.308011   0.000458
# 7   24.535866   0.000917
# 8   25.287584   0.001389
# 9   27.164527   0.001314
# 10  27.583888   0.002104

# %%
import scipy
qqplot(gjr_garch_t.std_resid, dist=scipy.stats.t, distargs=(gjr_garch_t.params.nu, ), line='45');

# %% [markdown]
# ### EGARCH(1, 1)
#
# $ y_t = \mu + \varepsilon_t $
#
# $ e_t  = \varepsilon_t / \sigma_t $
#
# $ \ln\sigma_t^2 = \omega + \alpha_1 \left|e_{t-1} - \sqrt{2/\pi}\right| + \gamma_1 e_{t-1} + \beta_1 \ln\sigma_{t-1} $

# %%
egarch = arch_model(y=df.DDM.dropna()*100, mean='Constant', vol='EGARCH', p=1, o=1, q=1).fit(update_freq=0)
print(egarch.summary())
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2060.212277035145
#             Iterations: 10
#             Function evaluations: 78
#             Gradient evaluations: 10
#                      Constant Mean - EGARCH Model Results
# ==============================================================================
# Dep. Variable:                    DDM   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                     EGARCH   Log-Likelihood:               -2060.21
# Distribution:                  Normal   AIC:                           4130.42
# Method:            Maximum Likelihood   BIC:                           4158.08
#                                         No. Observations:                 1866
# Date:                Sat, Dec 23 2023   Df Residuals:                     1865
# Time:                        10:37:49   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu            -0.0297  1.554e-02     -1.909  5.632e-02 [-6.011e-02,7.992e-04]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega         -0.0109  7.075e-03     -1.535      0.125 [-2.473e-02,3.008e-03]
# alpha[1]       0.2008  3.295e-02      6.095  1.096e-09      [  0.136,  0.265]
# gamma[1]      -0.0186  1.492e-02     -1.249      0.212 [-4.787e-02,1.061e-02]
# beta[1]        0.9713  9.337e-03    104.019      0.000      [  0.953,  0.990]
# =============================================================================
#
# Covariance estimator: robust
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1890: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if isinstance(table_val[pos], (np.float64, float)):
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1891: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   assert isinstance(table_val[pos], float)
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1892: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   converted = format_float_fixed(table_val[pos], *formats[i])

# %% [markdown]
# ### FIGARCH (fractionally integrated)
#
# Подробнее: https://stat.tugraz.at/AJS/ausg123/123Tayefi.pdf
#
# $ y_t = \mu + \varepsilon_t $
#
# $ \sigma_t = \nu_t \cdot \varepsilon_t $
#
# $ \sigma_t^2 = \omega + \left(1 - \beta L - \phi L (1-L)^d\right) \varepsilon_{t}^2 + \beta_1 \sigma_{t-1}^2 $

# %%
figarch = arch_model(y=df.DDM.dropna()*100, mean='Constant', vol='FIGARCH', p=1, q=1).fit(update_freq=0)
print(figarch.summary())
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2061.967585662759
#             Iterations: 9
#             Function evaluations: 68
#             Gradient evaluations: 9
#                     Constant Mean - FIGARCH Model Results
# ==============================================================================
# Dep. Variable:                    DDM   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                    FIGARCH   Log-Likelihood:               -2061.97
# Distribution:                  Normal   AIC:                           4133.94
# Method:            Maximum Likelihood   BIC:                           4161.59
#                                         No. Observations:                 1866
# Date:                Sat, Dec 23 2023   Df Residuals:                     1865
# Time:                        10:46:55   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu            -0.0208  1.638e-02     -1.270      0.204 [-5.290e-02,1.130e-02]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0198  7.543e-03      2.629  8.558e-03 [5.048e-03,3.462e-02]
# phi            0.1609  7.487e-02      2.149  3.162e-02   [1.417e-02,  0.308]
# d              0.5653      0.121      4.667  3.061e-06     [  0.328,  0.803]
# beta           0.6400  8.887e-02      7.202  5.942e-13     [  0.466,  0.814]
# ============================================================================
#
# Covariance estimator: robust
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1890: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if isinstance(table_val[pos], (np.float64, float)):
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1891: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   assert isinstance(table_val[pos], float)
# c:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\arch\univariate\base.py:1892: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   converted = format_float_fixed(table_val[pos], *formats[i])
